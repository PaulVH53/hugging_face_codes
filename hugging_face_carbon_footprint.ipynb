# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulVH53/hugging_face_codes/blob/main/hugging_face_carbon_footprint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install codecarbon
# Out:
# Collecting codecarbon
#   Downloading codecarbon-2.3.4-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 3.7 MB/s eta 0:00:00
# Collecting arrow (from codecarbon)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from codecarbon) (1.5.3)
# Collecting pynvml (from codecarbon)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from codecarbon) (2.31.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon) (9.0.0)
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon) (8.1.7)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon) (2.8.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->codecarbon) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->codecarbon) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.16.0)
# Installing collected packages: types-python-dateutil, rapidfuzz, pynvml, arrow, codecarbon
# Successfully installed arrow-1.3.0 codecarbon-2.3.4 pynvml-11.5.0 rapidfuzz-3.7.0 types-python-dateutil-2.9.0.20240316

# %%
from transformers import pipeline
from codecarbon import EmissionsTracker

# %%
tracker = EmissionsTracker()
# Out:
# [codecarbon INFO @ 12:25:35] [setup] RAM Tracking...
# [codecarbon INFO @ 12:25:35] [setup] GPU Tracking...
# [codecarbon INFO @ 12:25:35] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 12:25:35] [setup] CPU Tracking...
# [codecarbon WARNING @ 12:25:35] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 12:25:36] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 12:25:36] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 12:25:36] >>> Tracker's metadata:
# [codecarbon INFO @ 12:25:36]   Platform system: Linux-6.1.58+-x86_64-with-glibc2.35
# [codecarbon INFO @ 12:25:36]   Python version: 3.10.12
# [codecarbon INFO @ 12:25:36]   CodeCarbon version: 2.3.4
# [codecarbon INFO @ 12:25:36]   Available RAM : 12.675 GB
# [codecarbon INFO @ 12:25:36]   CPU count: 2
# [codecarbon INFO @ 12:25:36]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 12:25:36]   GPU count: 1
# [codecarbon INFO @ 12:25:36]   GPU model: 1 x Tesla T4

# %%
# %%time
tracker.start()
# test with GPU intensive code
classifier = pipeline("zero-shot-classification")
output = classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
print(output)
tracker.stop()
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# [codecarbon INFO @ 12:25:52] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 12:25:52] Energy consumed for all GPUs : 0.000043 kWh. Total GPU Power : 10.245612409430787 W
# [codecarbon INFO @ 12:25:52] Energy consumed for all CPUs : 0.000178 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:25:52] 0.000240 kWh of electricity used since the beginning.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [codecarbon INFO @ 12:26:02] Energy consumed for RAM : 0.000033 kWh. RAM Power : 4.753046035766602 W
# [codecarbon INFO @ 12:26:02] Energy consumed for all GPUs : 0.000072 kWh. Total GPU Power : 10.278212194140554 W
# [codecarbon INFO @ 12:26:02] Energy consumed for all CPUs : 0.000299 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:26:02] 0.000405 kWh of electricity used since the beginning.
# {'sequence': 'This is a course about the Transformers library', 'labels': ['education', 'business', 'politics'], 'scores': [0.8445991277694702, 0.11197404563426971, 0.043426841497421265]}
# CPU times: user 6.28 s, sys: 4.24 s, total: 10.5 s
# Wall time: 25.4 s
# "\nNo model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).\nUsing a pipeline without specifying a model name and revision in production is not recommended.\n/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:\nThe secret `HF_TOKEN` does not exist in your Colab secrets.\nTo authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.\nYou will be able to reuse this secret in all of your notebooks.\nPlease note that authentication is recommended but still optional to access public models or datasets.\n  warnings.warn(\nconfig.json:\u2007100%\n\u20071.15k/1.15k\u2007[00:00<00:00,\u200718.4kB/s]\nmodel.safetensors:\u2007100%\n\u20071.63G/1.63G\u2007[00:15<00:00,\u2007202MB/s]\n[codecarbon INFO @ 17:00:34] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.753046035766602 W\n[codecarbon INFO @ 17:00:34] Energy consumed for all GPUs : 0.000042 kWh. Total GPU Power : 9.953019489714174 W\n[codecarbon INFO @ 17:00:34] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W\n[codecarbon INFO @ 17:00:34] 0.000239 kWh of electricity used since the beginning.\ntokenizer_config.json:\u2007100%\n\u200726.0/26.0\u2007[00:00<00:00,\u20071.73kB/s]\nvocab.json:\u2007100%\n\u2007899k/899k\u2007[00:00<00:00,\u20074.55MB/s]\nmerges.txt:\u2007100%\n\u2007456k/456k\u2007[00:00<00:00,\u20073.46MB/s]\ntokenizer.json:\u2007100%\n\u20071.36M/1.36M\u2007[00:00<00:00,\u20075.18MB/s]\n[codecarbon INFO @ 17:00:44] Energy consumed for RAM : 0.000032 kWh. RAM Power : 4.753046035766602 W\n[codecarbon INFO @ 17:00:44] Energy consumed for all GPUs : 0.000067 kWh. Total GPU Power : 9.924178819646249 W\n[codecarbon INFO @ 17:00:44] Energy consumed for all CPUs : 0.000288 kWh. Total CPU Power : 42.5 W\n[codecarbon INFO @ 17:00:44] 0.000388 kWh of electricity used since the beginning.\n\n{'sequence': 'This is a course about the Transformers library',\n 'labels': ['education', 'business', 'politics'],\n 'scores': [0.8445966839790344, 0.11197589337825775, 0.04342742636799812]}\n\nCPU times: user 5.85 s, sys: 3.8 s, total: 9.64 s\nWall time: 24.4 s\n0.0001354929244424571\n"
